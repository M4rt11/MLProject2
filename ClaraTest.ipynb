# %%
import numpy as np # We'll be storing our data as numpy arrays
import os # For handling directories

import pandas as pd
from PIL import Image # For handling the images
import matplotlib.pyplot as plt
import matplotlib.image as mpimg # Plotting

# %%
lookup = dict()
reverselookup = dict()
count = 0
for j in os.listdir('/Users/Clara/Documents/GitHub/MLProject2/Domain1_csv'):
    if not j.startswith('.'): # If running this code locally, this is to
                              # ensure you aren't reading in hidden folders
        lookup[j] = count
        reverselookup[count] = j
        count = count + 1
lookup
# Out:
# {'Subject1-0-1.csv': 0,
#  'Subject1-0-10.csv': 1,
#  'Subject1-0-2.csv': 2,
#  'Subject1-0-3.csv': 3,
#  'Subject1-0-4.csv': 4,
#  'Subject1-0-5.csv': 5,
#  'Subject1-0-6.csv': 6,
#  'Subject1-0-7.csv': 7,
#  'Subject1-0-8.csv': 8,
#  'Subject1-0-9.csv': 9,
#  'Subject1-1-1.csv': 10,
#  'Subject1-1-10.csv': 11,
#  'Subject1-1-2.csv': 12,
#  'Subject1-1-3.csv': 13,
#  'Subject1-1-4.csv': 14,
#  'Subject1-1-5.csv': 15,
#  'Subject1-1-6.csv': 16,
#  'Subject1-1-7.csv': 17,
#  'Subject1-1-8.csv': 18,
#  'Subject1-1-9.csv': 19,
#  'Subject1-2-1.csv': 20,
#  'Subject1-2-10.csv': 21,
#  'Subject1-2-2.csv': 22,
#  'Subject1-2-3.csv': 23,
#  'Subject1-2-4.csv': 24,
#  'Subject1-2-5.csv': 25,
#  'Subject1-2-6.csv': 26,
#  'Subject1-2-7.csv': 27,
#  'Subject1-2-8.csv': 28,
#  'Subject1-2-9.csv': 29,
#  'Subject1-3-1.csv': 30,
#  'Subject1-3-10.csv': 31,
#  'Subject1-3-2.csv': 32,
#  'Subject1-3-3.csv': 33,
#  'Subject1-3-4.csv': 34,
#  'Subject1-3-5.csv': 35,
#  'Subject1-3-6.csv': 36,
# ...

# %%
#df = pd.read_csv('/Users/Clara/Documents/GitHub/MLProject2/Domain1_csv')
from os import listdir
from os.path import isfile, join
df = [f for f in listdir('/Users/Clara/Documents/GitHub/MLProject2/Domain1_csv') if isfile(join('/Users/Clara/Documents/GitHub/MLProject2/Domain1_csv', f))]
df.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [47], line 5
#       3 from os.path import isfile, join
#       4 df = [f for f in listdir('/Users/Clara/Documents/GitHub/MLProject2/Domain1_csv') if isfile(join('/Users/Clara/Documents/GitHub/MLProject2/Domain1_csv', f))]
# ----> 5 df.describe()
#
# AttributeError: 'list' object has no attribute 'describe'
